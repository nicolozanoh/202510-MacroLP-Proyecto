# %% [markdown]
# # 1. Importamos Paquetes

# %%
import numpy as np
import pandas as pd
import statsmodels as sm
import linearmodels as lm
import arch as arch
import matplotlib as plot
import os

if os.getcwd().split('\\')[len(os.getcwd().split('\\'))-1] != "202510-MacroLP-Proyecto":
    os.chdir("..")
print(os.getcwd())
# Out:
# c:\Users\NicolasLozano\OneDrive - Universidad de los andes\UNIVERSIDAD\9. NOVENO SEMESTRE\MACRO AVANZADA LP\202510-MacroLP-Proyecto

# %% [markdown]
# # 2. Procesamiento de los datos

# %% [markdown]
# Comenzamos cargando habilidades

# %%
df_abilities = pd.read_excel("stores\\onet\\raw\\abilities.xlsx")

df_skills = pd.read_excel("stores\\onet\\raw\\Skills.xlsx")

df_tasks = pd.read_excel("stores\\onet\\raw\\Task Ratings.xlsx")
